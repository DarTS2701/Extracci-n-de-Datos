# %% [markdown]
# <a href="https://colab.research.google.com/github/DarTS2701/Extracci-n-de-Datos/blob/main/Actividad_1_(Extracci%C3%B3n_de_Datos)_DTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Darinel Tellez Salazar A01734079**

# %% [markdown]
# # **Cargar Archivo y usar librerias**

# %%
#Importamos librerías requeridas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4371a7c2-ad3a-4aec-8006-8d3702b8e6cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4371a7c2-ad3a-4aec-8006-8d3702b8e6cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Convertir en dataframe
df= pd.read_csv("CountryTable.csv")
#df

# %%
#Imprimimos las primeras filas o registros del Dataframe (Imprimir el numero de filas que quiera en este caso 7 )
df.head(7)
# Out:
#   code                  name      continent                     region  \
# 0  ABW                 Aruba  North America                  Caribbean
# 1  AFG           Afghanistan           Asia  Southern and Central Asia
# 2  AGO                Angola         Africa             Central Africa
# 3  AIA              Anguilla  North America                  Caribbean
# 4  ALB               Albania         Europe            Southern Europe
# 5  AND               Andorra         Europe            Southern Europe
# 6  ANT  Netherlands Antilles  North America                  Caribbean
#
#    surface_area  independence_year  population  life_expectancy     gnp  \
# 0         193.0                NaN      103000             78.4   828.0
# 1      652090.0             1919.0    22720000             45.9  5976.0
# 2     1246700.0             1975.0    12878000             38.3  6648.0
# 3          96.0                NaN        8000             76.1    63.2
# ...

# %% [markdown]
# # **FILTROS VARIABLES CUALITATIVAS**

# %%
#Filtro por objeto
#Variables: Nombre
filtro1=df[df["name"] == "Mexico"]
filtro1
# Out:
#     code    name      continent           region  surface_area  \
# 135  MEX  Mexico  North America  Central America     1958201.0
#
#      independence_year  population  life_expectancy       gnp   gnp_old  \
# 135             1810.0    98881000             71.5  414972.0  401461.0
#
#     local_name   government_form        head_of_state  capital code2
# 135     Mexico  Federal Republic  Vicente Fox Quesada   2515.0    MX

# %%
#Filtro por filas
#Variable:Filas.

filtro2=df.iloc[[3,7,100] , : ]  #filas no consecutivas
filtro2
# Out:
#     code                            name      continent          region  \
# 3    AIA                        Anguilla  North America       Caribbean
# 7    ARE            united Arab Emirates           Asia     Middle East
# 100  IOT  British Indian Ocean Territory         Africa  Eastern Africa
#
#      surface_area  independence_year  population  life_expectancy      gnp  \
# 3            96.0                NaN        8000             76.1     63.2
# 7         83600.0             1971.0     2441000             74.1  37966.0
# 100          78.0                NaN           0              NaN      0.0
#
#      gnp_old                          local_name  \
# 3        NaN                            Anguilla
# 7    36846.0  Al-Imarat al- Arabiya al-Muttahida
# 100      NaN      British Indian Ocean Territory
#
#                    government_form                head_of_state  capital code2
# 3    Dependent Territory of the uK                 Elisabeth II     62.0    AI
# ...

# %%
#Filtro por columnas
#Variable: columnas
filtro3=df.iloc[ : , 3:7] #Columnas consecutivas
filtro3
# Out:
#                         region  surface_area  independence_year  population
# 0                    Caribbean         193.0                NaN      103000
# 1    Southern and Central Asia      652090.0             1919.0    22720000
# 2               Central Africa     1246700.0             1975.0    12878000
# 3                    Caribbean          96.0                NaN        8000
# 4              Southern Europe       28748.0             1912.0     3401200
# ..                         ...           ...                ...         ...
# 234                Middle East      527968.0             1918.0    18112000
# 235            Southern Europe      102173.0             1918.0    10640000
# 236            Southern Africa     1221037.0             1910.0    40377000
# 237             Eastern Africa      752618.0             1964.0     9169000
# 238             Eastern Africa      390757.0             1980.0    11669000
#
# [239 rows x 4 columns]

# %%
# Paso 1 filtro 4 Leer denuevo en df

df= pd.read_csv("CountryTable.csv", index_col=2)
df
# Out:
#               code          name                     region  surface_area  \
# continent
# North America  ABW         Aruba                  Caribbean         193.0
# Asia           AFG   Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO        Angola             Central Africa     1246700.0
# North America  AIA      Anguilla                  Caribbean          96.0
# Europe         ALB       Albania            Southern Europe       28748.0
# ...            ...           ...                        ...           ...
# Asia           YEM         Yemen                Middle East      527968.0
# Europe         YuG    Yugoslavia            Southern Europe      102173.0
# Africa         ZAF  South Africa            Southern Africa     1221037.0
# Africa         ZMB        Zambia             Eastern Africa      752618.0
# Africa         ZWE      Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
#Variable: Filas y Columnas

filtro4=df.loc[["Asia","Africa"], ["local_name"]]
filtro4
# Out:
#                                    local_name
# continent
# Asia                    Afganistan/Afqanestan
# Asia       Al-Imarat al- Arabiya al-Muttahida
# Asia                                 Hajastan
# Asia                               Azarbaycan
# Asia                               Bangladesh
# ...                                       ...
# Africa                               Tanzania
# Africa                                 uganda
# Africa                           South Africa
# Africa                                 Zambia
# Africa                               Zimbabwe
#
# [109 rows x 1 columns]

# %%
#Filtro por cabecera
#Variable: Cabecera
filtro5=df.head(7)
filtro5
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# North America  AIA              Anguilla                  Caribbean
# Europe         ALB               Albania            Southern Europe
# Europe         AND               Andorra            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# North America         193.0                NaN      103000             78.4
# Asia               652090.0             1919.0    22720000             45.9
# Africa            1246700.0             1975.0    12878000             38.3
# North America          96.0                NaN        8000             76.1
# ...

# %% [markdown]
# # **Filtro variables cuantitativas**

# %%
#Filtro por comparacion
#Variable: Capital
filtro6=df[df["capital"] > 2000]
filtro6
# Out:
#           code                                   name  \
# continent
# Europe     BLR                                Belarus
# Oceania    CCK                Cocos (Keeling) Islands
# Europe     CHE                            Switzerland
# Africa     CIV                           Cote dIvoire
# Africa     COD  Congo, The Democratic Republic of the
# ...        ...                                    ...
# Oceania    VuT                                Vanuatu
# Oceania    WLF                      Wallis and Futuna
# Oceania    WSM                                  Samoa
# Africa     ZMB                                 Zambia
# Africa     ZWE                               Zimbabwe
#
#                               region  surface_area  independence_year  \
# continent
# Europe                Eastern Europe      207600.0             1991.0
# Oceania    Australia and New Zealand          14.0                NaN
# Europe                Western Europe       41284.0             1499.0
# ...

# %% [markdown]
# # **Filtros de conectores logicos**

# %%
#Filtro AND
#Variables: gnp y government_form
filtro7=df[(df["gnp"] > 7000) & (df["government_form"] == "Republic")]
filtro7
# Out:
#               code                name                     region  \
# continent
# Asia           BGD          Bangladesh  Southern and Central Asia
# Europe         BGR            Bulgaria             Eastern Europe
# Europe         BLR             Belarus             Eastern Europe
# South America  BOL             Bolivia              South America
# South America  CHL               Chile              South America
# Africa         CIV        Cote dIvoire             Western Africa
# Africa         CMR            Cameroon             Central Africa
# South America  COL            Colombia              South America
# North America  CRI          Costa Rica            Central America
# Asia           CYP              Cyprus                Middle East
# Europe         CZE      Czech Republic             Eastern Europe
# North America  DOM  Dominican Republic                  Caribbean
# Africa         DZA             Algeria            Northern Africa
# ...

# %%
#Filtro or
#Variables: government_form y life_expectancy
filtro8=df[(df["life_expectancy"] > 80) | (df["government_form"] == "Federation")]
filtro8
# Out:
#           code         name           region  surface_area  independence_year  \
# continent
# Europe     AND      Andorra  Southern Europe         468.0             1278.0
# Europe     CHE  Switzerland   Western Europe       41284.0             1499.0
# Asia       JPN        Japan     Eastern Asia      377829.0             -660.0
# Asia       MAC        Macao     Eastern Asia          18.0                NaN
# Asia       SGP    Singapore   Southeast Asia         618.0             1965.0
# Europe     SMR   San Marino  Southern Europe          61.0              885.0
#
#            population  life_expectancy        gnp    gnp_old  \
# continent
# Europe          78000             83.5     1630.0        NaN
# Europe        7160400             79.6   264478.0   256092.0
# Asia        126714000             80.7  3787042.0  4192638.0
# Asia           473000             81.6     5749.0     5940.0
# Asia          3567000             80.1    86503.0    96318.0
# ...

# %%
#Filtro not
#Variable: Capital y surface_area
filtro9=df[~(df["capital"] >= 10000) & ~(df["surface_area"] >= 10000)]
filtro9
# Out:
#               code                              name           region  \
# continent
# North America  ABW                             Aruba        Caribbean
# North America  AIA                          Anguilla        Caribbean
# Europe         AND                           Andorra  Southern Europe
# North America  ANT              Netherlands Antilles        Caribbean
# Oceania        ASM                    American Samoa        Polynesia
# ...            ...                               ...              ...
# North America  VCT  Saint Vincent and the Grenadines        Caribbean
# North America  VGB           Virgin Islands, British        Caribbean
# North America  VIR              Virgin Islands, u.S.        Caribbean
# Oceania        WLF                 Wallis and Futuna        Polynesia
# Oceania        WSM                             Samoa        Polynesia
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# ...

# %% [markdown]
# # **Convertir a archivos cvv**

# %%
#Convertir archivo filtrado a CSV

filtro1.to_csv("Filtro1.csv")
filtro2.to_csv("Filtro2.csv")
filtro3.to_csv("Filtro3.csv")
filtro4.to_csv("Filtro4.csv")
filtro5.to_csv("Filtro5.csv")
filtro6.to_csv("Filtro6.csv")
filtro7.to_csv("Filtro7.csv")
filtro8.to_csv("Filtro8.csv")
filtro9.to_csv("Filtro9.csv")

# %%
#descargar archivo filtrado en csv filtro 9
from google.colab import files

files.download("Filtro1.csv")
files.download("Filtro2.csv")
files.download("Filtro3.csv")
files.download("Filtro4.csv")
files.download("Filtro5.csv")
files.download("Filtro6.csv")
files.download("Filtro7.csv")
files.download("Filtro8.csv")
files.download("Filtro9.csv")
